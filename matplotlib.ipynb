# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %mat
# Out:
# UsageError: Line magic function `%mat` not found.

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3 , 4])
plt.ylabel('funny numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4, 9], [-1, 2, 5, 8, 10], 'ro')
plt.show()

# %%
# t = np.arange(0, 5, 0.2)
# plt.plot(t, t, 'r-.', t, t**2, 'bs', t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x23002b38f50>,
#  <matplotlib.lines.Line2D at 0x23002b38dd0>,
#  <matplotlib.lines.Line2D at 0x23002b38e00>]

# %%
data = {
    'a': np.arange(500),
    'b': np.random.randint(0, 50, 50),
    'c': np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])
